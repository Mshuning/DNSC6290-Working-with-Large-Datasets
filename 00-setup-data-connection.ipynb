# %%
# This is the configuration object with the credentials to access Prof. Vaisman's data store on Azure. This is read only.

config = {"fs.azure.account.auth.type": "OAuth",
       "fs.azure.account.oauth.provider.type": "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider",
       "fs.azure.account.oauth2.client.id": "b36a8c16-0850-41e8-b900-b09af74cf517",
       "fs.azure.account.oauth2.client.secret": "MBr8Q~nfVBXG3mDe9OcPB3uhicIpSTft7zx3Obl_",
       "fs.azure.account.oauth2.client.endpoint": "https://login.microsoftonline.com/72f988bf-86f1-41af-91ab-2d7cd011db47/oauth2/token",
       "fs.azure.createRemoteFileSystemDuringInitialization": "true"}
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# This creates the mount point in a workspace DBFS directory called /mnt/course-datasets

dbutils.fs.mount(
source = "abfss://datasets@mvbdt.dfs.core.windows.net/",
mount_point = "/mnt/course-datasets",
extra_configs = config)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">ExecutionError</span>                            Traceback (most recent call last)
# ...

# %%
# Check that that blob location is mounted and list it's contents

dbutils.fs.ls('/mnt/course-datasets')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[3]: [FileInfo(path=&#39;dbfs:/mnt/course-datasets/2013-nyctaxi/&#39;, name=&#39;2013-nyctaxi/&#39;, size=0, modificationTime=1629423032000),
#  FileInfo(path=&#39;dbfs:/mnt/course-datasets/abc.txt&#39;, name=&#39;abc.txt&#39;, size=0, modificationTime=1603756716000),
#  FileInfo(path=&#39;dbfs:/mnt/course-datasets/airbnb/&#39;, name=&#39;airbnb/&#39;, size=0, modificationTime=1624459535000),
#  FileInfo(path=&#39;dbfs:/mnt/course-datasets/cfpb-hmda/&#39;, name=&#39;cfpb-hmda/&#39;, size=0, modificationTime=1629423114000),
# ...

# %%
# %fs ls dbfs:/mnt/course-datasets/project-data
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
